# %%
import re as re

#https://adventofcode.com/2023/day/1#part2
import day_1

# %%
def parse_numbers(a_string):
    print(a_string)
    number_map ={'one':'1',
                 'two':'2',
                 'three':'3',
                 'four':'4',
                 'five':'5',
                 'six':'6',
                 'seven':'7',
                 'eight':'8',
                 'nine':'9'}
    number_items_to_replace = []
    print(number_items_to_replace)
    for item in number_map.items():
        if item[0] in a_string:
            for each_substring in range(len(re.findall(item[0], a_string))):
                number_items_to_replace.append((item[0], item[-1], a_string.find(item[0])))
                number_items_to_replace.append((item[0], item[-1], a_string.rfind(item[0])))
    print(number_items_to_replace)
    #sort the items by index
    number_items_to_replace.sort(key = lambda item: item[-1])
    print(number_items_to_replace)
    if len(number_items_to_replace) > 0:
        first_item = number_items_to_replace[0]
        last_item = number_items_to_replace[-1]
        a_string = a_string.replace(first_item[0],first_item[1])
        a_string = a_string.replace(last_item[0],last_item[1])
            
    return a_string

# %%
test_input=['two1nine',
'eightwothree',
'abcone2threexyz',
'xtwone3four',
'4nineeightseven2',
'zoneight234',
'7pqrstsixteen']

# %%
def parse_numbers_for_rows(an_array):
    return [parse_numbers(a_row) for a_row in an_array]

# %%
test_input
#parse_numbers_for_rows(test_input)
# Out:
# ['two1nine',
#  'eightwothree',
#  'abcone2threexyz',
#  'xtwone3four',
#  '4nineeightseven2',
#  'zoneight234',
#  '7pqrstsixteen']

# %%
parse_numbers(test_input[1])
# Out:
# '8wo3'

# %%
def day_2():
    
    input = day_1.read_file('input.txt')
    input = parse_numbers_for_rows(input)
    input = day_1.convert_to_numeric(input)
    return day_1.sum_first_and_last(input)

# %%
day_2()
# Out:
# five3onelxjninenine45
#
# []
# [('one', '1', 5), ('one', '1', 5), ('five', '5', 0), ('five', '5', 0), ('nine', '9', 11), ('nine', '9', 15), ('nine', '9', 11), ('nine', '9', 15)]
# [('five', '5', 0), ('five', '5', 0), ('one', '1', 5), ('one', '1', 5), ('nine', '9', 11), ('nine', '9', 11), ('nine', '9', 15), ('nine', '9', 15)]
# six9mnfjmtsf2kfmznkxntninesevenrpmfjfpgsk
#
# []
# [('six', '6', 0), ('six', '6', 0), ('seven', '7', 26), ('seven', '7', 26), ('nine', '9', 22), ('nine', '9', 22)]
# [('six', '6', 0), ('six', '6', 0), ('nine', '9', 22), ('nine', '9', 22), ('seven', '7', 26), ('seven', '7', 26)]
# 9vkrmbpnine5two5cbktwo6
#
# []
# [('two', '2', 12), ('two', '2', 19), ('two', '2', 12), ('two', '2', 19), ('nine', '9', 7), ('nine', '9', 7)]
# [('nine', '9', 7), ('nine', '9', 7), ('two', '2', 12), ('two', '2', 12), ('two', '2', 19), ('two', '2', 19)]
# one1bdr6
#
# []
# [('one', '1', 0), ('one', '1', 0)]
# [('one', '1', 0), ('one', '1', 0)]
# ksvctznmffourtwovbb9four5five
#
# []
# [('two', '2', 13), ('two', '2', 13), ('four', '4', 9), ('four', '4', 20), ('four', '4', 9), ('four', '4', 20), ('five', '5', 25), ('five', '5', 25)]
# [('four', '4', 9), ('four', '4', 9), ('two', '2', 13), ('two', '2', 13), ('four', '4', 20), ('four', '4', 20), ('five', '5', 25), ('five', '5', 25)]
# 6nfhcklxlkg9jbqmqrrxmhn9two6
#
# []
# [('two', '2', 24), ('two', '2', 24)]
# [('two', '2', 24), ('two', '2', 24)]
# 9eight2six97dkth
#
# []
# [('six', '6', 7), ('six', '6', 7), ('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1), ('six', '6', 7), ('six', '6', 7)]
# sixgjqm64dkvcccvttnts
#
# []
# [('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0)]
# twofivefourb5four
#
# []
# [('two', '2', 0), ('two', '2', 0), ('four', '4', 7), ('four', '4', 13), ('four', '4', 7), ('four', '4', 13), ('five', '5', 3), ('five', '5', 3)]
# [('two', '2', 0), ('two', '2', 0), ('five', '5', 3), ('five', '5', 3), ('four', '4', 7), ('four', '4', 7), ('four', '4', 13), ('four', '4', 13)]
# gfive2
#
# []
# [('five', '5', 1), ('five', '5', 1)]
# [('five', '5', 1), ('five', '5', 1)]
# two18twocsxffivetwo4
#
# []
# [('two', '2', 0), ('two', '2', 16), ('two', '2', 0), ('two', '2', 16), ('two', '2', 0), ('two', '2', 16), ('five', '5', 12), ('five', '5', 12)]
# [('two', '2', 0), ('two', '2', 0), ('two', '2', 0), ('five', '5', 12), ('five', '5', 12), ('two', '2', 16), ('two', '2', 16), ('two', '2', 16)]
# rmchfml6four6twofive
#
# []
# [('two', '2', 13), ('two', '2', 13), ('four', '4', 8), ('four', '4', 8), ('five', '5', 16), ('five', '5', 16)]
# [('four', '4', 8), ('four', '4', 8), ('two', '2', 13), ('two', '2', 13), ('five', '5', 16), ('five', '5', 16)]
# 278eight
#
# []
# [('eight', '8', 3), ('eight', '8', 3)]
# [('eight', '8', 3), ('eight', '8', 3)]
# six5758jjqpgnvlztwolkcvxtjphd4
#
# []
# [('two', '2', 16), ('two', '2', 16), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('two', '2', 16), ('two', '2', 16)]
# fourz26ninethree8fourxrjlq
#
# []
# [('three', '3', 11), ('three', '3', 11), ('four', '4', 0), ('four', '4', 17), ('four', '4', 0), ('four', '4', 17), ('nine', '9', 7), ('nine', '9', 7)]
# [('four', '4', 0), ('four', '4', 0), ('nine', '9', 7), ('nine', '9', 7), ('three', '3', 11), ('three', '3', 11), ('four', '4', 17), ('four', '4', 17)]
# mhpx31fznvh6nnjbvjt6seven
#
# []
# [('seven', '7', 20), ('seven', '7', 20)]
# [('seven', '7', 20), ('seven', '7', 20)]
# kscs7kfvb1three2vnfjrtlvb
#
# []
# [('three', '3', 10), ('three', '3', 10)]
# [('three', '3', 10), ('three', '3', 10)]
# mcrxqxcxgq3eight9
#
# []
# [('eight', '8', 11), ('eight', '8', 11)]
# [('eight', '8', 11), ('eight', '8', 11)]
# 17eightone8ninebshqmfd
#
# []
# [('one', '1', 7), ('one', '1', 7), ('eight', '8', 2), ('eight', '8', 2), ('nine', '9', 11), ('nine', '9', 11)]
# [('eight', '8', 2), ('eight', '8', 2), ('one', '1', 7), ('one', '1', 7), ('nine', '9', 11), ('nine', '9', 11)]
# 1sgtxeightsix9
#
# []
# [('six', '6', 10), ('six', '6', 10), ('eight', '8', 5), ('eight', '8', 5)]
# [('eight', '8', 5), ('eight', '8', 5), ('six', '6', 10), ('six', '6', 10)]
# 96threeninetwo
#
# []
# [('two', '2', 11), ('two', '2', 11), ('three', '3', 2), ('three', '3', 2), ('nine', '9', 7), ('nine', '9', 7)]
# [('three', '3', 2), ('three', '3', 2), ('nine', '9', 7), ('nine', '9', 7), ('two', '2', 11), ('two', '2', 11)]
# five963fivexfgfgfbzrjjfive6
#
# []
# [('five', '5', 0), ('five', '5', 22), ('five', '5', 0), ('five', '5', 22), ('five', '5', 0), ('five', '5', 22)]
# [('five', '5', 0), ('five', '5', 0), ('five', '5', 0), ('five', '5', 22), ('five', '5', 22), ('five', '5', 22)]
# 5993zkdnfm
#
# []
# []
# []
# 1xnfxsqhninefour3eight
#
# []
# [('four', '4', 12), ('four', '4', 12), ('eight', '8', 17), ('eight', '8', 17), ('nine', '9', 8), ('nine', '9', 8)]
# [('nine', '9', 8), ('nine', '9', 8), ('four', '4', 12), ('four', '4', 12), ('eight', '8', 17), ('eight', '8', 17)]
# hplgtxvbfqrthreeonefour7
#
# []
# [('one', '1', 16), ('one', '1', 16), ('three', '3', 11), ('three', '3', 11), ('four', '4', 19), ('four', '4', 19)]
# [('three', '3', 11), ('three', '3', 11), ('one', '1', 16), ('one', '1', 16), ('four', '4', 19), ('four', '4', 19)]
# 84cclxfjrhptnfbcpd2
#
# []
# []
# []
# nineeight2kslgcchdxjppkthreeqhhs
#
# []
# [('three', '3', 23), ('three', '3', 23), ('eight', '8', 4), ('eight', '8', 4), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('eight', '8', 4), ('eight', '8', 4), ('three', '3', 23), ('three', '3', 23)]
# 5txpzlsixtwo41
#
# []
# [('two', '2', 9), ('two', '2', 9), ('six', '6', 6), ('six', '6', 6)]
# [('six', '6', 6), ('six', '6', 6), ('two', '2', 9), ('two', '2', 9)]
# 4nbkjmrt4nine
#
# []
# [('nine', '9', 9), ('nine', '9', 9)]
# [('nine', '9', 9), ('nine', '9', 9)]
# hnmvzknine1
#
# []
# [('nine', '9', 6), ('nine', '9', 6)]
# [('nine', '9', 6), ('nine', '9', 6)]
# 6525szrz
#
# []
# []
# []
# 1sixsixkxjxcbt1
#
# []
# [('six', '6', 1), ('six', '6', 4), ('six', '6', 1), ('six', '6', 4)]
# [('six', '6', 1), ('six', '6', 1), ('six', '6', 4), ('six', '6', 4)]
# 5vlj26mfxdjzb
#
# []
# []
# []
# 9xzkgd6eight9thjcjrsxggvkf2
#
# []
# [('eight', '8', 7), ('eight', '8', 7)]
# [('eight', '8', 7), ('eight', '8', 7)]
# 2tlvqgrkc42
#
# []
# []
# []
# one4five
#
# []
# [('one', '1', 0), ('one', '1', 0), ('five', '5', 4), ('five', '5', 4)]
# [('one', '1', 0), ('one', '1', 0), ('five', '5', 4), ('five', '5', 4)]
# 5six439eightsevenkkvng
#
# []
# [('six', '6', 1), ('six', '6', 1), ('seven', '7', 12), ('seven', '7', 12), ('eight', '8', 7), ('eight', '8', 7)]
# [('six', '6', 1), ('six', '6', 1), ('eight', '8', 7), ('eight', '8', 7), ('seven', '7', 12), ('seven', '7', 12)]
# hvmmqonethreezhvmzltf5seven9ttdx
#
# []
# [('one', '1', 5), ('one', '1', 5), ('three', '3', 8), ('three', '3', 8), ('seven', '7', 22), ('seven', '7', 22)]
# [('one', '1', 5), ('one', '1', 5), ('three', '3', 8), ('three', '3', 8), ('seven', '7', 22), ('seven', '7', 22)]
# 6eight6
#
# []
# [('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1)]
# hzpqtnjxz4cbkhqphlfpfourqflfjtg4mrztjlhbmmnine
#
# []
# [('four', '4', 20), ('four', '4', 20), ('nine', '9', 42), ('nine', '9', 42)]
# [('four', '4', 20), ('four', '4', 20), ('nine', '9', 42), ('nine', '9', 42)]
# sixsixdxcvbmr8bpbvfour6seven
#
# []
# [('four', '4', 18), ('four', '4', 18), ('six', '6', 0), ('six', '6', 3), ('six', '6', 0), ('six', '6', 3), ('seven', '7', 23), ('seven', '7', 23)]
# [('six', '6', 0), ('six', '6', 0), ('six', '6', 3), ('six', '6', 3), ('four', '4', 18), ('four', '4', 18), ('seven', '7', 23), ('seven', '7', 23)]
# nine3eight
#
# []
# [('eight', '8', 5), ('eight', '8', 5), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('eight', '8', 5), ('eight', '8', 5)]
# 8nqmbzvgpslsevenbfcrgqbtrzk
#
# []
# [('seven', '7', 11), ('seven', '7', 11)]
# [('seven', '7', 11), ('seven', '7', 11)]
# two7six2fourfourscrnine
#
# []
# [('two', '2', 0), ('two', '2', 0), ('four', '4', 8), ('four', '4', 12), ('four', '4', 8), ('four', '4', 12), ('six', '6', 4), ('six', '6', 4), ('nine', '9', 19), ('nine', '9', 19)]
# [('two', '2', 0), ('two', '2', 0), ('six', '6', 4), ('six', '6', 4), ('four', '4', 8), ('four', '4', 8), ('four', '4', 12), ('four', '4', 12), ('nine', '9', 19), ('nine', '9', 19)]
# 7dr3hhqnvrdsljqrl
#
# []
# []
# []
# 529dssfsfknzrffqsixtwo
#
# []
# [('two', '2', 19), ('two', '2', 19), ('six', '6', 16), ('six', '6', 16)]
# [('six', '6', 16), ('six', '6', 16), ('two', '2', 19), ('two', '2', 19)]
# 8sixsmcbslxvlxrkmhxhvgvvrgsixpgthrxlhrmfour
#
# []
# [('four', '4', 39), ('four', '4', 39), ('six', '6', 1), ('six', '6', 26), ('six', '6', 1), ('six', '6', 26)]
# [('six', '6', 1), ('six', '6', 1), ('six', '6', 26), ('six', '6', 26), ('four', '4', 39), ('four', '4', 39)]
# svqsjtlbdbkgjqbcvxhl4five
#
# []
# [('five', '5', 21), ('five', '5', 21)]
# [('five', '5', 21), ('five', '5', 21)]
# x8sevensix65eight
#
# []
# [('six', '6', 7), ('six', '6', 7), ('seven', '7', 2), ('seven', '7', 2), ('eight', '8', 12), ('eight', '8', 12)]
# [('seven', '7', 2), ('seven', '7', 2), ('six', '6', 7), ('six', '6', 7), ('eight', '8', 12), ('eight', '8', 12)]
# fsonemmszxjjx6nineteightvtzkhccgrm
#
# []
# [('one', '1', 2), ('one', '1', 2), ('eight', '8', 19), ('eight', '8', 19), ('nine', '9', 14), ('nine', '9', 14)]
# [('one', '1', 2), ('one', '1', 2), ('nine', '9', 14), ('nine', '9', 14), ('eight', '8', 19), ('eight', '8', 19)]
# 6sevenseven38cmskxvdkqlxktsszfnine
#
# []
# [('seven', '7', 1), ('seven', '7', 6), ('seven', '7', 1), ('seven', '7', 6), ('nine', '9', 30), ('nine', '9', 30)]
# [('seven', '7', 1), ('seven', '7', 1), ('seven', '7', 6), ('seven', '7', 6), ('nine', '9', 30), ('nine', '9', 30)]
# 75eightfjbqhksix3onextmlrftdxm9
#
# []
# [('one', '1', 17), ('one', '1', 17), ('six', '6', 13), ('six', '6', 13), ('eight', '8', 2), ('eight', '8', 2)]
# [('eight', '8', 2), ('eight', '8', 2), ('six', '6', 13), ('six', '6', 13), ('one', '1', 17), ('one', '1', 17)]
# 5hmngnfrglninenthconesixnine7
#
# []
# [('one', '1', 18), ('one', '1', 18), ('six', '6', 21), ('six', '6', 21), ('nine', '9', 10), ('nine', '9', 24), ('nine', '9', 10), ('nine', '9', 24)]
# [('nine', '9', 10), ('nine', '9', 10), ('one', '1', 18), ('one', '1', 18), ('six', '6', 21), ('six', '6', 21), ('nine', '9', 24), ('nine', '9', 24)]
# hgk4sevensixnineoneszsnhthree9
#
# []
# [('one', '1', 16), ('one', '1', 16), ('three', '3', 24), ('three', '3', 24), ('six', '6', 9), ('six', '6', 9), ('seven', '7', 4), ('seven', '7', 4), ('nine', '9', 12), ('nine', '9', 12)]
# [('seven', '7', 4), ('seven', '7', 4), ('six', '6', 9), ('six', '6', 9), ('nine', '9', 12), ('nine', '9', 12), ('one', '1', 16), ('one', '1', 16), ('three', '3', 24), ('three', '3', 24)]
# one98nxtghg9
#
# []
# [('one', '1', 0), ('one', '1', 0)]
# [('one', '1', 0), ('one', '1', 0)]
# 1sevenkqqckgxdnfour
#
# []
# [('four', '4', 15), ('four', '4', 15), ('seven', '7', 1), ('seven', '7', 1)]
# [('seven', '7', 1), ('seven', '7', 1), ('four', '4', 15), ('four', '4', 15)]
# 16three2onekjfcmfdfvhgmgninetwo
#
# []
# [('one', '1', 8), ('one', '1', 8), ('two', '2', 28), ('two', '2', 28), ('three', '3', 2), ('three', '3', 2), ('nine', '9', 24), ('nine', '9', 24)]
# [('three', '3', 2), ('three', '3', 2), ('one', '1', 8), ('one', '1', 8), ('nine', '9', 24), ('nine', '9', 24), ('two', '2', 28), ('two', '2', 28)]
# 1eight3fivesix87five
#
# []
# [('five', '5', 7), ('five', '5', 16), ('five', '5', 7), ('five', '5', 16), ('six', '6', 11), ('six', '6', 11), ('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1), ('five', '5', 7), ('five', '5', 7), ('six', '6', 11), ('six', '6', 11), ('five', '5', 16), ('five', '5', 16)]
# 2fourlhtncqs8gqssxlxczfive
#
# []
# [('four', '4', 1), ('four', '4', 1), ('five', '5', 22), ('five', '5', 22)]
# [('four', '4', 1), ('four', '4', 1), ('five', '5', 22), ('five', '5', 22)]
# ninejvzjqppsix21
#
# []
# [('six', '6', 11), ('six', '6', 11), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('six', '6', 11), ('six', '6', 11)]
# mkrd7249eight1pm
#
# []
# [('eight', '8', 8), ('eight', '8', 8)]
# [('eight', '8', 8), ('eight', '8', 8)]
# ppcxsevensevenxbjbvvzcd8one3ms
#
# []
# [('one', '1', 24), ('one', '1', 24), ('seven', '7', 4), ('seven', '7', 9), ('seven', '7', 4), ('seven', '7', 9)]
# [('seven', '7', 4), ('seven', '7', 4), ('seven', '7', 9), ('seven', '7', 9), ('one', '1', 24), ('one', '1', 24)]
# eightgnnlfive3ff49seven
#
# []
# [('five', '5', 9), ('five', '5', 9), ('seven', '7', 18), ('seven', '7', 18), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('five', '5', 9), ('five', '5', 9), ('seven', '7', 18), ('seven', '7', 18)]
# fngf62fourfivetwothree
#
# []
# [('two', '2', 14), ('two', '2', 14), ('three', '3', 17), ('three', '3', 17), ('four', '4', 6), ('four', '4', 6), ('five', '5', 10), ('five', '5', 10)]
# [('four', '4', 6), ('four', '4', 6), ('five', '5', 10), ('five', '5', 10), ('two', '2', 14), ('two', '2', 14), ('three', '3', 17), ('three', '3', 17)]
# onefour42rrzntqts
#
# []
# [('one', '1', 0), ('one', '1', 0), ('four', '4', 3), ('four', '4', 3)]
# [('one', '1', 0), ('one', '1', 0), ('four', '4', 3), ('four', '4', 3)]
# 41dzvh1
#
# []
# []
# []
# 3onefqltjzdrfourcpkfhceightwomc
#
# []
# [('one', '1', 1), ('one', '1', 1), ('two', '2', 26), ('two', '2', 26), ('four', '4', 12), ('four', '4', 12), ('eight', '8', 22), ('eight', '8', 22)]
# [('one', '1', 1), ('one', '1', 1), ('four', '4', 12), ('four', '4', 12), ('eight', '8', 22), ('eight', '8', 22), ('two', '2', 26), ('two', '2', 26)]
# 7ninezcqcmqsltfxltnpsgghzone3four
#
# []
# [('one', '1', 25), ('one', '1', 25), ('four', '4', 29), ('four', '4', 29), ('nine', '9', 1), ('nine', '9', 1)]
# [('nine', '9', 1), ('nine', '9', 1), ('one', '1', 25), ('one', '1', 25), ('four', '4', 29), ('four', '4', 29)]
# hrtwone3six4pjbs4tfvdsjqdtfglseven
#
# []
# [('one', '1', 4), ('one', '1', 4), ('two', '2', 2), ('two', '2', 2), ('six', '6', 8), ('six', '6', 8), ('seven', '7', 29), ('seven', '7', 29)]
# [('two', '2', 2), ('two', '2', 2), ('one', '1', 4), ('one', '1', 4), ('six', '6', 8), ('six', '6', 8), ('seven', '7', 29), ('seven', '7', 29)]
# 6lpxrrhvdslxgpjblcmgsgbdpdkfmzkr
#
# []
# []
# []
# llnshf1
#
# []
# []
# []
# seven9rvjqdhbfour
#
# []
# [('four', '4', 13), ('four', '4', 13), ('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0), ('four', '4', 13), ('four', '4', 13)]
# 1fivezb4six
#
# []
# [('five', '5', 1), ('five', '5', 1), ('six', '6', 8), ('six', '6', 8)]
# [('five', '5', 1), ('five', '5', 1), ('six', '6', 8), ('six', '6', 8)]
# 2282mchsix2onelz
#
# []
# [('one', '1', 11), ('one', '1', 11), ('six', '6', 7), ('six', '6', 7)]
# [('six', '6', 7), ('six', '6', 7), ('one', '1', 11), ('one', '1', 11)]
# 86eightwonmn
#
# []
# [('two', '2', 6), ('two', '2', 6), ('eight', '8', 2), ('eight', '8', 2)]
# [('eight', '8', 2), ('eight', '8', 2), ('two', '2', 6), ('two', '2', 6)]
# sevenlcznjrmcbzlpjvfivefhtfvl2vvsrbbcktnj
#
# []
# [('five', '5', 19), ('five', '5', 19), ('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0), ('five', '5', 19), ('five', '5', 19)]
# 2one819vsxclfour
#
# []
# [('one', '1', 1), ('one', '1', 1), ('four', '4', 12), ('four', '4', 12)]
# [('one', '1', 1), ('one', '1', 1), ('four', '4', 12), ('four', '4', 12)]
# dlm2nine
#
# []
# [('nine', '9', 4), ('nine', '9', 4)]
# [('nine', '9', 4), ('nine', '9', 4)]
# sxbdtwo9threetwo6
#
# []
# [('two', '2', 4), ('two', '2', 13), ('two', '2', 4), ('two', '2', 13), ('three', '3', 8), ('three', '3', 8)]
# [('two', '2', 4), ('two', '2', 4), ('three', '3', 8), ('three', '3', 8), ('two', '2', 13), ('two', '2', 13)]
# 4jfbc5rdzgsblrcgmqdh
#
# []
# []
# []
# nine7four28seven
#
# []
# [('four', '4', 5), ('four', '4', 5), ('seven', '7', 11), ('seven', '7', 11), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('four', '4', 5), ('four', '4', 5), ('seven', '7', 11), ('seven', '7', 11)]
# two1sixmjmxgjq412five
#
# []
# [('two', '2', 0), ('two', '2', 0), ('five', '5', 17), ('five', '5', 17), ('six', '6', 4), ('six', '6', 4)]
# [('two', '2', 0), ('two', '2', 0), ('six', '6', 4), ('six', '6', 4), ('five', '5', 17), ('five', '5', 17)]
# nine3hctlqv
#
# []
# [('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0)]
# twofour8eighttwo86two1
#
# []
# [('two', '2', 0), ('two', '2', 18), ('two', '2', 0), ('two', '2', 18), ('two', '2', 0), ('two', '2', 18), ('four', '4', 3), ('four', '4', 3), ('eight', '8', 8), ('eight', '8', 8)]
# [('two', '2', 0), ('two', '2', 0), ('two', '2', 0), ('four', '4', 3), ('four', '4', 3), ('eight', '8', 8), ('eight', '8', 8), ('two', '2', 18), ('two', '2', 18), ('two', '2', 18)]
# three4seveneightl
#
# []
# [('three', '3', 0), ('three', '3', 0), ('seven', '7', 6), ('seven', '7', 6), ('eight', '8', 11), ('eight', '8', 11)]
# [('three', '3', 0), ('three', '3', 0), ('seven', '7', 6), ('seven', '7', 6), ('eight', '8', 11), ('eight', '8', 11)]
# zx89btcqrsvpqzseven
#
# []
# [('seven', '7', 14), ('seven', '7', 14)]
# [('seven', '7', 14), ('seven', '7', 14)]
# 1chkglfseven
#
# []
# [('seven', '7', 7), ('seven', '7', 7)]
# [('seven', '7', 7), ('seven', '7', 7)]
# 4999xpmmeight3gxxkl
#
# []
# [('eight', '8', 8), ('eight', '8', 8)]
# [('eight', '8', 8), ('eight', '8', 8)]
# four88ninehhnbssxhbnseven
#
# []
# [('four', '4', 0), ('four', '4', 0), ('seven', '7', 20), ('seven', '7', 20), ('nine', '9', 6), ('nine', '9', 6)]
# [('four', '4', 0), ('four', '4', 0), ('nine', '9', 6), ('nine', '9', 6), ('seven', '7', 20), ('seven', '7', 20)]
# hsfvzbbxjlsrmtngrxxsevensix3
#
# []
# [('six', '6', 24), ('six', '6', 24), ('seven', '7', 19), ('seven', '7', 19)]
# [('seven', '7', 19), ('seven', '7', 19), ('six', '6', 24), ('six', '6', 24)]
# qccnqvfnkkkvsixktsixnine1twoneq
#
# []
# [('one', '1', 27), ('one', '1', 27), ('two', '2', 25), ('two', '2', 25), ('six', '6', 12), ('six', '6', 17), ('six', '6', 12), ('six', '6', 17), ('nine', '9', 20), ('nine', '9', 20)]
# [('six', '6', 12), ('six', '6', 12), ('six', '6', 17), ('six', '6', 17), ('nine', '9', 20), ('nine', '9', 20), ('two', '2', 25), ('two', '2', 25), ('one', '1', 27), ('one', '1', 27)]
# 2sevengsplvndctjgntsix3seven
#
# []
# [('six', '6', 19), ('six', '6', 19), ('seven', '7', 1), ('seven', '7', 23), ('seven', '7', 1), ('seven', '7', 23)]
# [('seven', '7', 1), ('seven', '7', 1), ('six', '6', 19), ('six', '6', 19), ('seven', '7', 23), ('seven', '7', 23)]
# eight782two428four
#
# []
# [('two', '2', 8), ('two', '2', 8), ('four', '4', 14), ('four', '4', 14), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('two', '2', 8), ('two', '2', 8), ('four', '4', 14), ('four', '4', 14)]
# five37shzmklkb4nhddk8
#
# []
# [('five', '5', 0), ('five', '5', 0)]
# [('five', '5', 0), ('five', '5', 0)]
# eightthree6qskmkzs
#
# []
# [('three', '3', 5), ('three', '3', 5), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('three', '3', 5), ('three', '3', 5)]
# cmkvmr3srbsnq7onefourbfsrbjvr
#
# []
# [('one', '1', 14), ('one', '1', 14), ('four', '4', 17), ('four', '4', 17)]
# [('one', '1', 14), ('one', '1', 14), ('four', '4', 17), ('four', '4', 17)]
# t3mtgjq4stm84
#
# []
# []
# []
# fiveseven2grlmfhmfg8bsb
#
# []
# [('five', '5', 0), ('five', '5', 0), ('seven', '7', 4), ('seven', '7', 4)]
# [('five', '5', 0), ('five', '5', 0), ('seven', '7', 4), ('seven', '7', 4)]
# 9bgbplvtzstdsevenonedrbxhftrxgmqftjmdrr
#
# []
# [('one', '1', 17), ('one', '1', 17), ('seven', '7', 12), ('seven', '7', 12)]
# [('seven', '7', 12), ('seven', '7', 12), ('one', '1', 17), ('one', '1', 17)]
# sixfivezptk6
#
# []
# [('five', '5', 3), ('five', '5', 3), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('five', '5', 3), ('five', '5', 3)]
# 8mftfiveninedgfmtwo9three9
#
# []
# [('two', '2', 16), ('two', '2', 16), ('three', '3', 20), ('three', '3', 20), ('five', '5', 4), ('five', '5', 4), ('nine', '9', 8), ('nine', '9', 8)]
# [('five', '5', 4), ('five', '5', 4), ('nine', '9', 8), ('nine', '9', 8), ('two', '2', 16), ('two', '2', 16), ('three', '3', 20), ('three', '3', 20)]
# pscstrfnrpllhone5fivefourtwo
#
# []
# [('one', '1', 13), ('one', '1', 13), ('two', '2', 25), ('two', '2', 25), ('four', '4', 21), ('four', '4', 21), ('five', '5', 17), ('five', '5', 17)]
# [('one', '1', 13), ('one', '1', 13), ('five', '5', 17), ('five', '5', 17), ('four', '4', 21), ('four', '4', 21), ('two', '2', 25), ('two', '2', 25)]
# five33
#
# []
# [('five', '5', 0), ('five', '5', 0)]
# [('five', '5', 0), ('five', '5', 0)]
# 4threegfs
#
# []
# [('three', '3', 1), ('three', '3', 1)]
# [('three', '3', 1), ('three', '3', 1)]
# 6sixthreebvq5
#
# []
# [('three', '3', 4), ('three', '3', 4), ('six', '6', 1), ('six', '6', 1)]
# [('six', '6', 1), ('six', '6', 1), ('three', '3', 4), ('three', '3', 4)]
# tsjvdsljzfgfive6threemqjfhrsqkgfznbt
#
# []
# [('three', '3', 16), ('three', '3', 16), ('five', '5', 11), ('five', '5', 11)]
# [('five', '5', 11), ('five', '5', 11), ('three', '3', 16), ('three', '3', 16)]
# six8five
#
# []
# [('five', '5', 4), ('five', '5', 4), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('five', '5', 4), ('five', '5', 4)]
# twoznvvqgmd5jsxltq
#
# []
# [('two', '2', 0), ('two', '2', 0)]
# [('two', '2', 0), ('two', '2', 0)]
# zvh9one
#
# []
# [('one', '1', 4), ('one', '1', 4)]
# [('one', '1', 4), ('one', '1', 4)]
# 4threesevenfivesix2hmm
#
# []
# [('three', '3', 1), ('three', '3', 1), ('five', '5', 11), ('five', '5', 11), ('six', '6', 15), ('six', '6', 15), ('seven', '7', 6), ('seven', '7', 6)]
# [('three', '3', 1), ('three', '3', 1), ('seven', '7', 6), ('seven', '7', 6), ('five', '5', 11), ('five', '5', 11), ('six', '6', 15), ('six', '6', 15)]
# l8ccxxhqqjb1qltqxht9qknltdbmdbmone
#
# []
# [('one', '1', 31), ('one', '1', 31)]
# [('one', '1', 31), ('one', '1', 31)]
# psevenfournine7bzphqxtfmfhsbtxxldhcqj
#
# []
# [('four', '4', 6), ('four', '4', 6), ('seven', '7', 1), ('seven', '7', 1), ('nine', '9', 10), ('nine', '9', 10)]
# [('seven', '7', 1), ('seven', '7', 1), ('four', '4', 6), ('four', '4', 6), ('nine', '9', 10), ('nine', '9', 10)]
# 9bzxmpnlqmt8
#
# []
# []
# []
# two73nineeighteight
#
# []
# [('two', '2', 0), ('two', '2', 0), ('eight', '8', 9), ('eight', '8', 14), ('eight', '8', 9), ('eight', '8', 14), ('nine', '9', 5), ('nine', '9', 5)]
# [('two', '2', 0), ('two', '2', 0), ('nine', '9', 5), ('nine', '9', 5), ('eight', '8', 9), ('eight', '8', 9), ('eight', '8', 14), ('eight', '8', 14)]
# 5sixseven
#
# []
# [('six', '6', 1), ('six', '6', 1), ('seven', '7', 4), ('seven', '7', 4)]
# [('six', '6', 1), ('six', '6', 1), ('seven', '7', 4), ('seven', '7', 4)]
# eightthree98112
#
# []
# [('three', '3', 5), ('three', '3', 5), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('three', '3', 5), ('three', '3', 5)]
# eight4zbnpgjqlgntpl
#
# []
# [('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0)]
# fourhg8twoone1xhllbxfrtwoneq
#
# []
# [('one', '1', 10), ('one', '1', 24), ('one', '1', 10), ('one', '1', 24), ('two', '2', 7), ('two', '2', 22), ('two', '2', 7), ('two', '2', 22), ('four', '4', 0), ('four', '4', 0)]
# [('four', '4', 0), ('four', '4', 0), ('two', '2', 7), ('two', '2', 7), ('one', '1', 10), ('one', '1', 10), ('two', '2', 22), ('two', '2', 22), ('one', '1', 24), ('one', '1', 24)]
# jzonevsfhdcxzkmcxfhngleight2four
#
# []
# [('one', '1', 2), ('one', '1', 2), ('four', '4', 28), ('four', '4', 28), ('eight', '8', 22), ('eight', '8', 22)]
# [('one', '1', 2), ('one', '1', 2), ('eight', '8', 22), ('eight', '8', 22), ('four', '4', 28), ('four', '4', 28)]
# 6two4ndnscxkqlzszlkslzk28
#
# []
# [('two', '2', 1), ('two', '2', 1)]
# [('two', '2', 1), ('two', '2', 1)]
# 1foursix25695cp
#
# []
# [('four', '4', 1), ('four', '4', 1), ('six', '6', 5), ('six', '6', 5)]
# [('four', '4', 1), ('four', '4', 1), ('six', '6', 5), ('six', '6', 5)]
# 9hgvmtfiveeightdm
#
# []
# [('five', '5', 6), ('five', '5', 6), ('eight', '8', 10), ('eight', '8', 10)]
# [('five', '5', 6), ('five', '5', 6), ('eight', '8', 10), ('eight', '8', 10)]
# 7162nine
#
# []
# [('nine', '9', 4), ('nine', '9', 4)]
# [('nine', '9', 4), ('nine', '9', 4)]
# seven7tqssone
#
# []
# [('one', '1', 10), ('one', '1', 10), ('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0), ('one', '1', 10), ('one', '1', 10)]
# 234cgsdfq7
#
# []
# []
# []
# 9eightvpvvztrsrbtvgkzg
#
# []
# [('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1)]
# two882nine6eightsixz
#
# []
# [('two', '2', 0), ('two', '2', 0), ('six', '6', 16), ('six', '6', 16), ('eight', '8', 11), ('eight', '8', 11), ('nine', '9', 6), ('nine', '9', 6)]
# [('two', '2', 0), ('two', '2', 0), ('nine', '9', 6), ('nine', '9', 6), ('eight', '8', 11), ('eight', '8', 11), ('six', '6', 16), ('six', '6', 16)]
# 9nineqqltckg
#
# []
# [('nine', '9', 1), ('nine', '9', 1)]
# [('nine', '9', 1), ('nine', '9', 1)]
# lgtlzthree21jrx
#
# []
# [('three', '3', 5), ('three', '3', 5)]
# [('three', '3', 5), ('three', '3', 5)]
# 42seven
#
# []
# [('seven', '7', 2), ('seven', '7', 2)]
# [('seven', '7', 2), ('seven', '7', 2)]
# 6pl3ckfqjchmnplblhkrd36jbflxf
#
# []
# []
# []
# fpmkbm7three
#
# []
# [('three', '3', 7), ('three', '3', 7)]
# [('three', '3', 7), ('three', '3', 7)]
# 5twoonegccshhdrnfour1
#
# []
# [('one', '1', 4), ('one', '1', 4), ('two', '2', 1), ('two', '2', 1), ('four', '4', 16), ('four', '4', 16)]
# [('two', '2', 1), ('two', '2', 1), ('one', '1', 4), ('one', '1', 4), ('four', '4', 16), ('four', '4', 16)]
# onexbeightsdoneseven2four
#
# []
# [('one', '1', 0), ('one', '1', 12), ('one', '1', 0), ('one', '1', 12), ('four', '4', 21), ('four', '4', 21), ('seven', '7', 15), ('seven', '7', 15), ('eight', '8', 5), ('eight', '8', 5)]
# [('one', '1', 0), ('one', '1', 0), ('eight', '8', 5), ('eight', '8', 5), ('one', '1', 12), ('one', '1', 12), ('seven', '7', 15), ('seven', '7', 15), ('four', '4', 21), ('four', '4', 21)]
# three5sixxj
#
# []
# [('three', '3', 0), ('three', '3', 0), ('six', '6', 6), ('six', '6', 6)]
# [('three', '3', 0), ('three', '3', 0), ('six', '6', 6), ('six', '6', 6)]
# eightxqzntcpscxbqrsix8three
#
# []
# [('three', '3', 22), ('three', '3', 22), ('six', '6', 18), ('six', '6', 18), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('six', '6', 18), ('six', '6', 18), ('three', '3', 22), ('three', '3', 22)]
# eightfourthree9eightvvhhlfourp
#
# []
# [('three', '3', 9), ('three', '3', 9), ('four', '4', 5), ('four', '4', 25), ('four', '4', 5), ('four', '4', 25), ('eight', '8', 0), ('eight', '8', 15), ('eight', '8', 0), ('eight', '8', 15)]
# [('eight', '8', 0), ('eight', '8', 0), ('four', '4', 5), ('four', '4', 5), ('three', '3', 9), ('three', '3', 9), ('eight', '8', 15), ('eight', '8', 15), ('four', '4', 25), ('four', '4', 25)]
# seven67vdktlg51
#
# []
# [('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0)]
# xbgjvvonesbtthfkdvntwo35
#
# []
# [('one', '1', 6), ('one', '1', 6), ('two', '2', 19), ('two', '2', 19)]
# [('one', '1', 6), ('one', '1', 6), ('two', '2', 19), ('two', '2', 19)]
# fltjrv152sixvmtwofour
#
# []
# [('two', '2', 14), ('two', '2', 14), ('four', '4', 17), ('four', '4', 17), ('six', '6', 9), ('six', '6', 9)]
# [('six', '6', 9), ('six', '6', 9), ('two', '2', 14), ('two', '2', 14), ('four', '4', 17), ('four', '4', 17)]
# fourfour6zkjdlrckdbfxthreefive
#
# []
# [('three', '3', 21), ('three', '3', 21), ('four', '4', 0), ('four', '4', 4), ('four', '4', 0), ('four', '4', 4), ('five', '5', 26), ('five', '5', 26)]
# [('four', '4', 0), ('four', '4', 0), ('four', '4', 4), ('four', '4', 4), ('three', '3', 21), ('three', '3', 21), ('five', '5', 26), ('five', '5', 26)]
# kkrllbsnglkvxxzjmqvdgsfpzx18foureightseveneight
#
# []
# [('four', '4', 28), ('four', '4', 28), ('seven', '7', 37), ('seven', '7', 37), ('eight', '8', 32), ('eight', '8', 42), ('eight', '8', 32), ('eight', '8', 42)]
# [('four', '4', 28), ('four', '4', 28), ('eight', '8', 32), ('eight', '8', 32), ('seven', '7', 37), ('seven', '7', 37), ('eight', '8', 42), ('eight', '8', 42)]
# xvmjqznggz7pgrxcfcqj
#
# []
# []
# []
# 5two9eight
#
# []
# [('two', '2', 1), ('two', '2', 1), ('eight', '8', 5), ('eight', '8', 5)]
# [('two', '2', 1), ('two', '2', 1), ('eight', '8', 5), ('eight', '8', 5)]
# 2rbninevmltplhj6nine
#
# []
# [('nine', '9', 3), ('nine', '9', 16), ('nine', '9', 3), ('nine', '9', 16)]
# [('nine', '9', 3), ('nine', '9', 3), ('nine', '9', 16), ('nine', '9', 16)]
# 4snzlftzltjfbxdq
#
# []
# []
# []
# 5gcpdxdjsftntzgbfnkbsjone
#
# []
# [('one', '1', 22), ('one', '1', 22)]
# [('one', '1', 22), ('one', '1', 22)]
# onetwoninenine58onekmtdfn6
#
# []
# [('one', '1', 0), ('one', '1', 16), ('one', '1', 0), ('one', '1', 16), ('two', '2', 3), ('two', '2', 3), ('nine', '9', 6), ('nine', '9', 10), ('nine', '9', 6), ('nine', '9', 10)]
# [('one', '1', 0), ('one', '1', 0), ('two', '2', 3), ('two', '2', 3), ('nine', '9', 6), ('nine', '9', 6), ('nine', '9', 10), ('nine', '9', 10), ('one', '1', 16), ('one', '1', 16)]
# four68four8two5
#
# []
# [('two', '2', 11), ('two', '2', 11), ('four', '4', 0), ('four', '4', 6), ('four', '4', 0), ('four', '4', 6)]
# [('four', '4', 0), ('four', '4', 0), ('four', '4', 6), ('four', '4', 6), ('two', '2', 11), ('two', '2', 11)]
# lczh9
#
# []
# []
# []
# sevensevenfivefour141j
#
# []
# [('four', '4', 14), ('four', '4', 14), ('five', '5', 10), ('five', '5', 10), ('seven', '7', 0), ('seven', '7', 5), ('seven', '7', 0), ('seven', '7', 5)]
# [('seven', '7', 0), ('seven', '7', 0), ('seven', '7', 5), ('seven', '7', 5), ('five', '5', 10), ('five', '5', 10), ('four', '4', 14), ('four', '4', 14)]
# bmnrnlvfpvjsfourn1one3
#
# []
# [('one', '1', 18), ('one', '1', 18), ('four', '4', 12), ('four', '4', 12)]
# [('four', '4', 12), ('four', '4', 12), ('one', '1', 18), ('one', '1', 18)]
# 3nineone7fourfbfmjmpcpv6kgvzndbgpn
#
# []
# [('one', '1', 5), ('one', '1', 5), ('four', '4', 9), ('four', '4', 9), ('nine', '9', 1), ('nine', '9', 1)]
# [('nine', '9', 1), ('nine', '9', 1), ('one', '1', 5), ('one', '1', 5), ('four', '4', 9), ('four', '4', 9)]
# 633sevenczmjrstsp195
#
# []
# [('seven', '7', 3), ('seven', '7', 3)]
# [('seven', '7', 3), ('seven', '7', 3)]
# sixvrcjmsveight3
#
# []
# [('six', '6', 0), ('six', '6', 0), ('eight', '8', 10), ('eight', '8', 10)]
# [('six', '6', 0), ('six', '6', 0), ('eight', '8', 10), ('eight', '8', 10)]
# cgfhxt4
#
# []
# []
# []
# 4lqvqgsf37nrszkrhtjg91djsxdlrksk
#
# []
# []
# []
# ninefivefive11four1eight
#
# []
# [('four', '4', 14), ('four', '4', 14), ('five', '5', 4), ('five', '5', 8), ('five', '5', 4), ('five', '5', 8), ('eight', '8', 19), ('eight', '8', 19), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('five', '5', 4), ('five', '5', 4), ('five', '5', 8), ('five', '5', 8), ('four', '4', 14), ('four', '4', 14), ('eight', '8', 19), ('eight', '8', 19)]
# 76twovxfqrdksoneeightpgf4
#
# []
# [('one', '1', 13), ('one', '1', 13), ('two', '2', 2), ('two', '2', 2), ('eight', '8', 16), ('eight', '8', 16)]
# [('two', '2', 2), ('two', '2', 2), ('one', '1', 13), ('one', '1', 13), ('eight', '8', 16), ('eight', '8', 16)]
# vhn9xnlhd3fivesix
#
# []
# [('five', '5', 10), ('five', '5', 10), ('six', '6', 14), ('six', '6', 14)]
# [('five', '5', 10), ('five', '5', 10), ('six', '6', 14), ('six', '6', 14)]
# 3sevenzpqvxhtsix
#
# []
# [('six', '6', 13), ('six', '6', 13), ('seven', '7', 1), ('seven', '7', 1)]
# [('seven', '7', 1), ('seven', '7', 1), ('six', '6', 13), ('six', '6', 13)]
# dkkeightwosixcdngxqddtj4
#
# []
# [('two', '2', 7), ('two', '2', 7), ('six', '6', 10), ('six', '6', 10), ('eight', '8', 3), ('eight', '8', 3)]
# [('eight', '8', 3), ('eight', '8', 3), ('two', '2', 7), ('two', '2', 7), ('six', '6', 10), ('six', '6', 10)]
# nineqqsdkmkhhsixpd4
#
# []
# [('six', '6', 13), ('six', '6', 13), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('six', '6', 13), ('six', '6', 13)]
# 6five54
#
# []
# [('five', '5', 1), ('five', '5', 1)]
# [('five', '5', 1), ('five', '5', 1)]
# tlzst3sevenvdthkfn3
#
# []
# [('seven', '7', 6), ('seven', '7', 6)]
# [('seven', '7', 6), ('seven', '7', 6)]
# nineone2
#
# []
# [('one', '1', 4), ('one', '1', 4), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('one', '1', 4), ('one', '1', 4)]
# fcxeightwoeighthxpgfkfourone3
#
# []
# [('one', '1', 25), ('one', '1', 25), ('two', '2', 7), ('two', '2', 7), ('four', '4', 21), ('four', '4', 21), ('eight', '8', 3), ('eight', '8', 10), ('eight', '8', 3), ('eight', '8', 10)]
# [('eight', '8', 3), ('eight', '8', 3), ('two', '2', 7), ('two', '2', 7), ('eight', '8', 10), ('eight', '8', 10), ('four', '4', 21), ('four', '4', 21), ('one', '1', 25), ('one', '1', 25)]
# 9llcdpmninepvcbdonexfxgdfchtkgnmnljpnfb
#
# []
# [('one', '1', 16), ('one', '1', 16), ('nine', '9', 7), ('nine', '9', 7)]
# [('nine', '9', 7), ('nine', '9', 7), ('one', '1', 16), ('one', '1', 16)]
# qrjdrbrrxrldbsq8threepbsdpbbtps9four
#
# []
# [('three', '3', 16), ('three', '3', 16), ('four', '4', 32), ('four', '4', 32)]
# [('three', '3', 16), ('three', '3', 16), ('four', '4', 32), ('four', '4', 32)]
# 299eightone
#
# []
# [('one', '1', 8), ('one', '1', 8), ('eight', '8', 3), ('eight', '8', 3)]
# [('eight', '8', 3), ('eight', '8', 3), ('one', '1', 8), ('one', '1', 8)]
# fjzoneight99
#
# []
# [('one', '1', 3), ('one', '1', 3), ('eight', '8', 5), ('eight', '8', 5)]
# [('one', '1', 3), ('one', '1', 3), ('eight', '8', 5), ('eight', '8', 5)]
# zz8three9
#
# []
# [('three', '3', 3), ('three', '3', 3)]
# [('three', '3', 3), ('three', '3', 3)]
# eight4mfzshls167eight
#
# []
# [('eight', '8', 0), ('eight', '8', 16), ('eight', '8', 0), ('eight', '8', 16)]
# [('eight', '8', 0), ('eight', '8', 0), ('eight', '8', 16), ('eight', '8', 16)]
# five1kmgmnpfhsp42
#
# []
# [('five', '5', 0), ('five', '5', 0)]
# [('five', '5', 0), ('five', '5', 0)]
# 6one67one
#
# []
# [('one', '1', 1), ('one', '1', 6), ('one', '1', 1), ('one', '1', 6)]
# [('one', '1', 1), ('one', '1', 1), ('one', '1', 6), ('one', '1', 6)]
# fivefncmv3dgsx8lmssvqfthk6seven
#
# []
# [('five', '5', 0), ('five', '5', 0), ('seven', '7', 26), ('seven', '7', 26)]
# [('five', '5', 0), ('five', '5', 0), ('seven', '7', 26), ('seven', '7', 26)]
# vlsbqreightseven77onermkfdsvjxkmn
#
# []
# [('one', '1', 18), ('one', '1', 18), ('seven', '7', 11), ('seven', '7', 11), ('eight', '8', 6), ('eight', '8', 6)]
# [('eight', '8', 6), ('eight', '8', 6), ('seven', '7', 11), ('seven', '7', 11), ('one', '1', 18), ('one', '1', 18)]
# 86hxzstkkb
#
# []
# []
# []
# 79mnxgbnl
#
# []
# []
# []
# 15nineone9ninesevenddrbrxj
#
# []
# [('one', '1', 6), ('one', '1', 6), ('seven', '7', 14), ('seven', '7', 14), ('nine', '9', 2), ('nine', '9', 10), ('nine', '9', 2), ('nine', '9', 10)]
# [('nine', '9', 2), ('nine', '9', 2), ('one', '1', 6), ('one', '1', 6), ('nine', '9', 10), ('nine', '9', 10), ('seven', '7', 14), ('seven', '7', 14)]
# 21rkt24dfour8four
#
# []
# [('four', '4', 8), ('four', '4', 13), ('four', '4', 8), ('four', '4', 13)]
# [('four', '4', 8), ('four', '4', 8), ('four', '4', 13), ('four', '4', 13)]
# blxv68threeseven
#
# []
# [('three', '3', 6), ('three', '3', 6), ('seven', '7', 11), ('seven', '7', 11)]
# [('three', '3', 6), ('three', '3', 6), ('seven', '7', 11), ('seven', '7', 11)]
# rbvkltwo3gpmmfmnpone9
#
# []
# [('one', '1', 17), ('one', '1', 17), ('two', '2', 5), ('two', '2', 5)]
# [('two', '2', 5), ('two', '2', 5), ('one', '1', 17), ('one', '1', 17)]
# hrqss7
#
# []
# []
# []
# six1threethree1
#
# []
# [('three', '3', 4), ('three', '3', 9), ('three', '3', 4), ('three', '3', 9), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('three', '3', 4), ('three', '3', 4), ('three', '3', 9), ('three', '3', 9)]
# frfctnmmhrmfr8
#
# []
# []
# []
# bfzsvmcxhbthreefivezlb981
#
# []
# [('three', '3', 10), ('three', '3', 10), ('five', '5', 15), ('five', '5', 15)]
# [('three', '3', 10), ('three', '3', 10), ('five', '5', 15), ('five', '5', 15)]
# phrlbcbd6vrf8gkrtnlprn
#
# []
# []
# []
# txbxjb47svrfd4lrdkfbknb2gj
#
# []
# []
# []
# fivefour6dnjqbmznkssevenone
#
# []
# [('one', '1', 24), ('one', '1', 24), ('four', '4', 4), ('four', '4', 4), ('five', '5', 0), ('five', '5', 0), ('seven', '7', 19), ('seven', '7', 19)]
# [('five', '5', 0), ('five', '5', 0), ('four', '4', 4), ('four', '4', 4), ('seven', '7', 19), ('seven', '7', 19), ('one', '1', 24), ('one', '1', 24)]
# 32eighttwonedn
#
# []
# [('one', '1', 9), ('one', '1', 9), ('two', '2', 7), ('two', '2', 7), ('eight', '8', 2), ('eight', '8', 2)]
# [('eight', '8', 2), ('eight', '8', 2), ('two', '2', 7), ('two', '2', 7), ('one', '1', 9), ('one', '1', 9)]
# gxzqseventwo4eight
#
# []
# [('two', '2', 9), ('two', '2', 9), ('seven', '7', 4), ('seven', '7', 4), ('eight', '8', 13), ('eight', '8', 13)]
# [('seven', '7', 4), ('seven', '7', 4), ('two', '2', 9), ('two', '2', 9), ('eight', '8', 13), ('eight', '8', 13)]
# eighttwo53ktqxjfjfive3
#
# []
# [('two', '2', 5), ('two', '2', 5), ('five', '5', 17), ('five', '5', 17), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('two', '2', 5), ('two', '2', 5), ('five', '5', 17), ('five', '5', 17)]
# 64four3gjjtjq
#
# []
# [('four', '4', 2), ('four', '4', 2)]
# [('four', '4', 2), ('four', '4', 2)]
# tmrv9sevenfive
#
# []
# [('five', '5', 10), ('five', '5', 10), ('seven', '7', 5), ('seven', '7', 5)]
# [('seven', '7', 5), ('seven', '7', 5), ('five', '5', 10), ('five', '5', 10)]
# 9seven81
#
# []
# [('seven', '7', 1), ('seven', '7', 1)]
# [('seven', '7', 1), ('seven', '7', 1)]
# fivefourktwozzszqveightseven7
#
# []
# [('two', '2', 9), ('two', '2', 9), ('four', '4', 4), ('four', '4', 4), ('five', '5', 0), ('five', '5', 0), ('seven', '7', 23), ('seven', '7', 23), ('eight', '8', 18), ('eight', '8', 18)]
# [('five', '5', 0), ('five', '5', 0), ('four', '4', 4), ('four', '4', 4), ('two', '2', 9), ('two', '2', 9), ('eight', '8', 18), ('eight', '8', 18), ('seven', '7', 23), ('seven', '7', 23)]
# three8bninetwofivednine
#
# []
# [('two', '2', 11), ('two', '2', 11), ('three', '3', 0), ('three', '3', 0), ('five', '5', 14), ('five', '5', 14), ('nine', '9', 7), ('nine', '9', 19), ('nine', '9', 7), ('nine', '9', 19)]
# [('three', '3', 0), ('three', '3', 0), ('nine', '9', 7), ('nine', '9', 7), ('two', '2', 11), ('two', '2', 11), ('five', '5', 14), ('five', '5', 14), ('nine', '9', 19), ('nine', '9', 19)]
# nineone7qzdcglxjtkchjfpqrdfive6nine
#
# []
# [('one', '1', 4), ('one', '1', 4), ('five', '5', 26), ('five', '5', 26), ('nine', '9', 0), ('nine', '9', 31), ('nine', '9', 0), ('nine', '9', 31)]
# [('nine', '9', 0), ('nine', '9', 0), ('one', '1', 4), ('one', '1', 4), ('five', '5', 26), ('five', '5', 26), ('nine', '9', 31), ('nine', '9', 31)]
# 4hjsqzppdqseightblhpdxgjmfmrsrz
#
# []
# [('eight', '8', 11), ('eight', '8', 11)]
# [('eight', '8', 11), ('eight', '8', 11)]
# fouronefour5fourjxls3
#
# []
# [('one', '1', 4), ('one', '1', 4), ('four', '4', 0), ('four', '4', 12), ('four', '4', 0), ('four', '4', 12), ('four', '4', 0), ('four', '4', 12)]
# [('four', '4', 0), ('four', '4', 0), ('four', '4', 0), ('one', '1', 4), ('one', '1', 4), ('four', '4', 12), ('four', '4', 12), ('four', '4', 12)]
# sixsevensevenoneeightgssdqpgfrx6rpkdljlsjs
#
# []
# [('one', '1', 13), ('one', '1', 13), ('six', '6', 0), ('six', '6', 0), ('seven', '7', 3), ('seven', '7', 8), ('seven', '7', 3), ('seven', '7', 8), ('eight', '8', 16), ('eight', '8', 16)]
# [('six', '6', 0), ('six', '6', 0), ('seven', '7', 3), ('seven', '7', 3), ('seven', '7', 8), ('seven', '7', 8), ('one', '1', 13), ('one', '1', 13), ('eight', '8', 16), ('eight', '8', 16)]
# two4cpvhzxnbqmk4
#
# []
# [('two', '2', 0), ('two', '2', 0)]
# [('two', '2', 0), ('two', '2', 0)]
# 98czdfivecpmvztnc87
#
# []
# [('five', '5', 5), ('five', '5', 5)]
# [('five', '5', 5), ('five', '5', 5)]
# 5chczkvdd
#
# []
# []
# []
# dhndkdsbf7qp1
#
# []
# []
# []
# tdbpx1qbf
#
# []
# []
# []
# 358tbjnc
#
# []
# []
# []
# two6264six
#
# []
# [('two', '2', 0), ('two', '2', 0), ('six', '6', 7), ('six', '6', 7)]
# [('two', '2', 0), ('two', '2', 0), ('six', '6', 7), ('six', '6', 7)]
# 55snf
#
# []
# []
# []
# eight7kpgsjrntszcmvrjqcs2two4four
#
# []
# [('two', '2', 25), ('two', '2', 25), ('four', '4', 29), ('four', '4', 29), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('two', '2', 25), ('two', '2', 25), ('four', '4', 29), ('four', '4', 29)]
# cpjxfgxdngjrnpbkfskpstm5nineseven5nine
#
# []
# [('seven', '7', 28), ('seven', '7', 28), ('nine', '9', 24), ('nine', '9', 34), ('nine', '9', 24), ('nine', '9', 34)]
# [('nine', '9', 24), ('nine', '9', 24), ('seven', '7', 28), ('seven', '7', 28), ('nine', '9', 34), ('nine', '9', 34)]
# one2jxrsxlll1xpkeightztcfnsqqr
#
# []
# [('one', '1', 0), ('one', '1', 0), ('eight', '8', 16), ('eight', '8', 16)]
# [('one', '1', 0), ('one', '1', 0), ('eight', '8', 16), ('eight', '8', 16)]
# 2sevensevenzdb
#
# []
# [('seven', '7', 1), ('seven', '7', 6), ('seven', '7', 1), ('seven', '7', 6)]
# [('seven', '7', 1), ('seven', '7', 1), ('seven', '7', 6), ('seven', '7', 6)]
# trpcnb536fourninethree
#
# []
# [('three', '3', 17), ('three', '3', 17), ('four', '4', 9), ('four', '4', 9), ('nine', '9', 13), ('nine', '9', 13)]
# [('four', '4', 9), ('four', '4', 9), ('nine', '9', 13), ('nine', '9', 13), ('three', '3', 17), ('three', '3', 17)]
# bkhoneightblkqzbblmv8rkcg
#
# []
# [('one', '1', 3), ('one', '1', 3), ('eight', '8', 5), ('eight', '8', 5)]
# [('one', '1', 3), ('one', '1', 3), ('eight', '8', 5), ('eight', '8', 5)]
# zqmmzmsqjghtf915
#
# []
# []
# []
# 3zxdzklnlbdvcqspm
#
# []
# []
# []
# sevensixtwo8rsvdmc
#
# []
# [('two', '2', 8), ('two', '2', 8), ('six', '6', 5), ('six', '6', 5), ('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0), ('six', '6', 5), ('six', '6', 5), ('two', '2', 8), ('two', '2', 8)]
# 8two8
#
# []
# [('two', '2', 1), ('two', '2', 1)]
# [('two', '2', 1), ('two', '2', 1)]
# eightoneqlcrrlq4four
#
# []
# [('one', '1', 5), ('one', '1', 5), ('four', '4', 16), ('four', '4', 16), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('one', '1', 5), ('one', '1', 5), ('four', '4', 16), ('four', '4', 16)]
# hlfhtwovvmzkzn5xklvc9
#
# []
# [('two', '2', 4), ('two', '2', 4)]
# [('two', '2', 4), ('two', '2', 4)]
# fournncdgvxk6crvsqjcj58
#
# []
# [('four', '4', 0), ('four', '4', 0)]
# [('four', '4', 0), ('four', '4', 0)]
# 7941sevenfour
#
# []
# [('four', '4', 9), ('four', '4', 9), ('seven', '7', 4), ('seven', '7', 4)]
# [('seven', '7', 4), ('seven', '7', 4), ('four', '4', 9), ('four', '4', 9)]
# mshlfglzlvcpcn2ninefiveninemlzkxspxsz2
#
# []
# [('five', '5', 19), ('five', '5', 19), ('nine', '9', 15), ('nine', '9', 23), ('nine', '9', 15), ('nine', '9', 23)]
# [('nine', '9', 15), ('nine', '9', 15), ('five', '5', 19), ('five', '5', 19), ('nine', '9', 23), ('nine', '9', 23)]
# 46sixone4eightrcmxrmhnmj6pmj
#
# []
# [('one', '1', 5), ('one', '1', 5), ('six', '6', 2), ('six', '6', 2), ('eight', '8', 9), ('eight', '8', 9)]
# [('six', '6', 2), ('six', '6', 2), ('one', '1', 5), ('one', '1', 5), ('eight', '8', 9), ('eight', '8', 9)]
# jblfkrc1threefivefourbxd3
#
# []
# [('three', '3', 8), ('three', '3', 8), ('four', '4', 17), ('four', '4', 17), ('five', '5', 13), ('five', '5', 13)]
# [('three', '3', 8), ('three', '3', 8), ('five', '5', 13), ('five', '5', 13), ('four', '4', 17), ('four', '4', 17)]
# prhvcsmvjx85one
#
# []
# [('one', '1', 12), ('one', '1', 12)]
# [('one', '1', 12), ('one', '1', 12)]
# sstdseven3twobrfour3zthzhtkmc2
#
# []
# [('two', '2', 10), ('two', '2', 10), ('four', '4', 15), ('four', '4', 15), ('seven', '7', 4), ('seven', '7', 4)]
# [('seven', '7', 4), ('seven', '7', 4), ('two', '2', 10), ('two', '2', 10), ('four', '4', 15), ('four', '4', 15)]
# 9threeqdnninesqvsjdch55zzjrntdv
#
# []
# [('three', '3', 1), ('three', '3', 1), ('nine', '9', 9), ('nine', '9', 9)]
# [('three', '3', 1), ('three', '3', 1), ('nine', '9', 9), ('nine', '9', 9)]
# fourbljt53gfkjkjtcpnlxcb
#
# []
# [('four', '4', 0), ('four', '4', 0)]
# [('four', '4', 0), ('four', '4', 0)]
# qrtlkzcthreefnxlcnfsqqvhsix62one3
#
# []
# [('one', '1', 29), ('one', '1', 29), ('three', '3', 7), ('three', '3', 7), ('six', '6', 24), ('six', '6', 24)]
# [('three', '3', 7), ('three', '3', 7), ('six', '6', 24), ('six', '6', 24), ('one', '1', 29), ('one', '1', 29)]
# knb7three7srrqbfhthreefive5
#
# []
# [('three', '3', 4), ('three', '3', 17), ('three', '3', 4), ('three', '3', 17), ('five', '5', 22), ('five', '5', 22)]
# [('three', '3', 4), ('three', '3', 4), ('three', '3', 17), ('three', '3', 17), ('five', '5', 22), ('five', '5', 22)]
# sevengcf128btrnrtgbmj3mtzv
#
# []
# [('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0)]
# brzvbdtwo63three4pjcjmzgfk8
#
# []
# [('two', '2', 6), ('two', '2', 6), ('three', '3', 11), ('three', '3', 11)]
# [('two', '2', 6), ('two', '2', 6), ('three', '3', 11), ('three', '3', 11)]
# 6klnsftm
#
# []
# []
# []
# eight6sevensevensixfhgnjzgrcqdseven
#
# []
# [('six', '6', 16), ('six', '6', 16), ('seven', '7', 6), ('seven', '7', 30), ('seven', '7', 6), ('seven', '7', 30), ('seven', '7', 6), ('seven', '7', 30), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('seven', '7', 6), ('seven', '7', 6), ('seven', '7', 6), ('six', '6', 16), ('six', '6', 16), ('seven', '7', 30), ('seven', '7', 30), ('seven', '7', 30)]
# six2ckhhflcdjkrc2sdtgkzx4four
#
# []
# [('four', '4', 25), ('four', '4', 25), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('four', '4', 25), ('four', '4', 25)]
# six49
#
# []
# [('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0)]
# 56eight
#
# []
# [('eight', '8', 2), ('eight', '8', 2)]
# [('eight', '8', 2), ('eight', '8', 2)]
# gfivevqqkz7
#
# []
# [('five', '5', 1), ('five', '5', 1)]
# [('five', '5', 1), ('five', '5', 1)]
# twoseven1kfzjcxjj
#
# []
# [('two', '2', 0), ('two', '2', 0), ('seven', '7', 3), ('seven', '7', 3)]
# [('two', '2', 0), ('two', '2', 0), ('seven', '7', 3), ('seven', '7', 3)]
# 5xsbckzsevenfdcd6ffh
#
# []
# [('seven', '7', 7), ('seven', '7', 7)]
# [('seven', '7', 7), ('seven', '7', 7)]
# five6fivezpdm19
#
# []
# [('five', '5', 0), ('five', '5', 5), ('five', '5', 0), ('five', '5', 5)]
# [('five', '5', 0), ('five', '5', 0), ('five', '5', 5), ('five', '5', 5)]
# eightsix1zlrvvtflhqbmgnjnthcdbjthree
#
# []
# [('three', '3', 31), ('three', '3', 31), ('six', '6', 5), ('six', '6', 5), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('six', '6', 5), ('six', '6', 5), ('three', '3', 31), ('three', '3', 31)]
# 9lbmb1gflnxtnine
#
# []
# [('nine', '9', 12), ('nine', '9', 12)]
# [('nine', '9', 12), ('nine', '9', 12)]
# 1eightxdrp566ljjtmbpng
#
# []
# [('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1)]
# twoqbfl5four67three9
#
# []
# [('two', '2', 0), ('two', '2', 0), ('three', '3', 14), ('three', '3', 14), ('four', '4', 8), ('four', '4', 8)]
# [('two', '2', 0), ('two', '2', 0), ('four', '4', 8), ('four', '4', 8), ('three', '3', 14), ('three', '3', 14)]
# six3sevenseven13
#
# []
# [('six', '6', 0), ('six', '6', 0), ('seven', '7', 4), ('seven', '7', 9), ('seven', '7', 4), ('seven', '7', 9)]
# [('six', '6', 0), ('six', '6', 0), ('seven', '7', 4), ('seven', '7', 4), ('seven', '7', 9), ('seven', '7', 9)]
# seven4onenine4ccnmtbdtj
#
# []
# [('one', '1', 6), ('one', '1', 6), ('seven', '7', 0), ('seven', '7', 0), ('nine', '9', 9), ('nine', '9', 9)]
# [('seven', '7', 0), ('seven', '7', 0), ('one', '1', 6), ('one', '1', 6), ('nine', '9', 9), ('nine', '9', 9)]
# hxzhqqtqdssevenfivecjfhlxmrbk2rdxsix8
#
# []
# [('five', '5', 15), ('five', '5', 15), ('six', '6', 33), ('six', '6', 33), ('seven', '7', 10), ('seven', '7', 10)]
# [('seven', '7', 10), ('seven', '7', 10), ('five', '5', 15), ('five', '5', 15), ('six', '6', 33), ('six', '6', 33)]
# three6brccmgbkdxgj7
#
# []
# [('three', '3', 0), ('three', '3', 0)]
# [('three', '3', 0), ('three', '3', 0)]
# 961
#
# []
# []
# []
# 1ninesevensix6sixonetwonine
#
# []
# [('one', '1', 17), ('one', '1', 17), ('two', '2', 20), ('two', '2', 20), ('six', '6', 10), ('six', '6', 14), ('six', '6', 10), ('six', '6', 14), ('seven', '7', 5), ('seven', '7', 5), ('nine', '9', 1), ('nine', '9', 23), ('nine', '9', 1), ('nine', '9', 23)]
# [('nine', '9', 1), ('nine', '9', 1), ('seven', '7', 5), ('seven', '7', 5), ('six', '6', 10), ('six', '6', 10), ('six', '6', 14), ('six', '6', 14), ('one', '1', 17), ('one', '1', 17), ('two', '2', 20), ('two', '2', 20), ('nine', '9', 23), ('nine', '9', 23)]
# 4hlvbbs5pnjxbpd5xpvxfmn
#
# []
# []
# []
# kkvjtnjk3nineseventwotrjntwo
#
# []
# [('two', '2', 18), ('two', '2', 25), ('two', '2', 18), ('two', '2', 25), ('seven', '7', 13), ('seven', '7', 13), ('nine', '9', 9), ('nine', '9', 9)]
# [('nine', '9', 9), ('nine', '9', 9), ('seven', '7', 13), ('seven', '7', 13), ('two', '2', 18), ('two', '2', 18), ('two', '2', 25), ('two', '2', 25)]
# 669zgrhxlrgtpeighttfrrqmhthree7eight
#
# []
# [('three', '3', 25), ('three', '3', 25), ('eight', '8', 13), ('eight', '8', 31), ('eight', '8', 13), ('eight', '8', 31)]
# [('eight', '8', 13), ('eight', '8', 13), ('three', '3', 25), ('three', '3', 25), ('eight', '8', 31), ('eight', '8', 31)]
# pltqnfslttlhfour7
#
# []
# [('four', '4', 12), ('four', '4', 12)]
# [('four', '4', 12), ('four', '4', 12)]
# 31grzj
#
# []
# []
# []
# qkqtwoneeighttgp8944cpxxksr3
#
# []
# [('one', '1', 5), ('one', '1', 5), ('two', '2', 3), ('two', '2', 3), ('eight', '8', 8), ('eight', '8', 8)]
# [('two', '2', 3), ('two', '2', 3), ('one', '1', 5), ('one', '1', 5), ('eight', '8', 8), ('eight', '8', 8)]
# onelpvxtcj35zrllxzt
#
# []
# [('one', '1', 0), ('one', '1', 0)]
# [('one', '1', 0), ('one', '1', 0)]
# fcccc7
#
# []
# []
# []
# 3eight1
#
# []
# [('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1)]
# 4five3ggdpskqjfrbngmq7nine
#
# []
# [('five', '5', 1), ('five', '5', 1), ('nine', '9', 22), ('nine', '9', 22)]
# [('five', '5', 1), ('five', '5', 1), ('nine', '9', 22), ('nine', '9', 22)]
# 8cnbxpfpm
#
# []
# []
# []
# frmvkjxxggbssxlftzninelvvtvscl77ninefxdtrpvjfv
#
# []
# [('nine', '9', 18), ('nine', '9', 32), ('nine', '9', 18), ('nine', '9', 32)]
# [('nine', '9', 18), ('nine', '9', 18), ('nine', '9', 32), ('nine', '9', 32)]
# rxkcvjbvhk84
#
# []
# []
# []
# 6twonegz
#
# []
# [('one', '1', 3), ('one', '1', 3), ('two', '2', 1), ('two', '2', 1)]
# ...
#
# []
# [('seven', '7', 0), ('seven', '7', 0)]
# [('seven', '7', 0), ('seven', '7', 0)]
# fivetmxkjczpjninefive5pss3onetwonetmq
#
# []
# [('one', '1', 26), ('one', '1', 31), ('one', '1', 26), ('one', '1', 31), ('two', '2', 29), ('two', '2', 29), ('five', '5', 0), ('five', '5', 17), ('five', '5', 0), ('five', '5', 17), ('nine', '9', 13), ('nine', '9', 13)]
# [('five', '5', 0), ('five', '5', 0), ('nine', '9', 13), ('nine', '9', 13), ('five', '5', 17), ('five', '5', 17), ('one', '1', 26), ('one', '1', 26), ('two', '2', 29), ('two', '2', 29), ('one', '1', 31), ('one', '1', 31)]
# 4klstxhhpjzfkvonefourthreezkchsjone
#
# []
# [('one', '1', 14), ('one', '1', 32), ('one', '1', 14), ('one', '1', 32), ('three', '3', 21), ('three', '3', 21), ('four', '4', 17), ('four', '4', 17)]
# [('one', '1', 14), ('one', '1', 14), ('four', '4', 17), ('four', '4', 17), ('three', '3', 21), ('three', '3', 21), ('one', '1', 32), ('one', '1', 32)]
# rxljd9four94six4
#
# []
# [('four', '4', 6), ('four', '4', 6), ('six', '6', 12), ('six', '6', 12)]
# [('four', '4', 6), ('four', '4', 6), ('six', '6', 12), ('six', '6', 12)]
# 5fgnnfjl2three
#
# []
# [('three', '3', 9), ('three', '3', 9)]
# [('three', '3', 9), ('three', '3', 9)]
# ngfq4rsevenvngjtrjvvkcnvrs
#
# []
# [('seven', '7', 6), ('seven', '7', 6)]
# [('seven', '7', 6), ('seven', '7', 6)]
# eighttqc7frmxtfoureightonetwo
#
# []
# [('one', '1', 23), ('one', '1', 23), ('two', '2', 26), ('two', '2', 26), ('four', '4', 14), ('four', '4', 14), ('eight', '8', 0), ('eight', '8', 18), ('eight', '8', 0), ('eight', '8', 18)]
# [('eight', '8', 0), ('eight', '8', 0), ('four', '4', 14), ('four', '4', 14), ('eight', '8', 18), ('eight', '8', 18), ('one', '1', 23), ('one', '1', 23), ('two', '2', 26), ('two', '2', 26)]
# threegtzbdttnd6tnlsevenlfqbnvlpg8r
#
# []
# [('three', '3', 0), ('three', '3', 0), ('seven', '7', 18), ('seven', '7', 18)]
# [('three', '3', 0), ('three', '3', 0), ('seven', '7', 18), ('seven', '7', 18)]
# dsjfrslnxb8fournineshzqfourmxjvhone
#
# []
# [('one', '1', 32), ('one', '1', 32), ('four', '4', 11), ('four', '4', 23), ('four', '4', 11), ('four', '4', 23), ('nine', '9', 15), ('nine', '9', 15)]
# [('four', '4', 11), ('four', '4', 11), ('nine', '9', 15), ('nine', '9', 15), ('four', '4', 23), ('four', '4', 23), ('one', '1', 32), ('one', '1', 32)]
# 27bxtdmsshfourtwo86
#
# []
# [('two', '2', 14), ('two', '2', 14), ('four', '4', 10), ('four', '4', 10)]
# [('four', '4', 10), ('four', '4', 10), ('two', '2', 14), ('two', '2', 14)]
# threesevensix5vc
#
# []
# [('three', '3', 0), ('three', '3', 0), ('six', '6', 10), ('six', '6', 10), ('seven', '7', 5), ('seven', '7', 5)]
# [('three', '3', 0), ('three', '3', 0), ('seven', '7', 5), ('seven', '7', 5), ('six', '6', 10), ('six', '6', 10)]
# 44seven
#
# []
# [('seven', '7', 2), ('seven', '7', 2)]
# [('seven', '7', 2), ('seven', '7', 2)]
# two1eighttwosevensix8
#
# []
# [('two', '2', 0), ('two', '2', 9), ('two', '2', 0), ('two', '2', 9), ('six', '6', 17), ('six', '6', 17), ('seven', '7', 12), ('seven', '7', 12), ('eight', '8', 4), ('eight', '8', 4)]
# [('two', '2', 0), ('two', '2', 0), ('eight', '8', 4), ('eight', '8', 4), ('two', '2', 9), ('two', '2', 9), ('seven', '7', 12), ('seven', '7', 12), ('six', '6', 17), ('six', '6', 17)]
# hbnlzhbfvztwo4kjfzktwotwo2sqgvdbrjbg
#
# []
# [('two', '2', 10), ('two', '2', 22), ('two', '2', 10), ('two', '2', 22), ('two', '2', 10), ('two', '2', 22)]
# [('two', '2', 10), ('two', '2', 10), ('two', '2', 10), ('two', '2', 22), ('two', '2', 22), ('two', '2', 22)]
# two6sv6
#
# []
# [('two', '2', 0), ('two', '2', 0)]
# [('two', '2', 0), ('two', '2', 0)]
# gdgdsbtwo98vhdlf3eightwohgv
#
# []
# [('two', '2', 6), ('two', '2', 21), ('two', '2', 6), ('two', '2', 21), ('eight', '8', 17), ('eight', '8', 17)]
# [('two', '2', 6), ('two', '2', 6), ('eight', '8', 17), ('eight', '8', 17), ('two', '2', 21), ('two', '2', 21)]
# tztgspssevendqpxvtsftgclhct4mktj4
#
# []
# [('seven', '7', 7), ('seven', '7', 7)]
# [('seven', '7', 7), ('seven', '7', 7)]
# xbnzpglcdgrrcttvjxx4
#
# []
# []
# []
# dkzeightwotwo1gpfn3njqzkxhhsc
#
# []
# [('two', '2', 7), ('two', '2', 10), ('two', '2', 7), ('two', '2', 10), ('eight', '8', 3), ('eight', '8', 3)]
# [('eight', '8', 3), ('eight', '8', 3), ('two', '2', 7), ('two', '2', 7), ('two', '2', 10), ('two', '2', 10)]
# 1ggsixfive
#
# []
# [('five', '5', 6), ('five', '5', 6), ('six', '6', 3), ('six', '6', 3)]
# [('six', '6', 3), ('six', '6', 3), ('five', '5', 6), ('five', '5', 6)]
# 2eighthlhthdn
#
# []
# [('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1)]
# hczrldvxffninemzbhsv2two5eightwozfh
#
# []
# [('two', '2', 21), ('two', '2', 29), ('two', '2', 21), ('two', '2', 29), ('eight', '8', 25), ('eight', '8', 25), ('nine', '9', 10), ('nine', '9', 10)]
# [('nine', '9', 10), ('nine', '9', 10), ('two', '2', 21), ('two', '2', 21), ('eight', '8', 25), ('eight', '8', 25), ('two', '2', 29), ('two', '2', 29)]
# nksxdqvpgq6jhzl
#
# []
# []
# []
# tkvjsxzgrp7four4thlzxone33
#
# []
# [('one', '1', 21), ('one', '1', 21), ('four', '4', 11), ('four', '4', 11)]
# [('four', '4', 11), ('four', '4', 11), ('one', '1', 21), ('one', '1', 21)]
# bpncmqxsprpkbpznfivebvhd7lpqspfhsgq1
#
# []
# [('five', '5', 16), ('five', '5', 16)]
# [('five', '5', 16), ('five', '5', 16)]
# threeone174fourkbkqvtjlfn
#
# []
# [('one', '1', 5), ('one', '1', 5), ('three', '3', 0), ('three', '3', 0), ('four', '4', 11), ('four', '4', 11)]
# [('three', '3', 0), ('three', '3', 0), ('one', '1', 5), ('one', '1', 5), ('four', '4', 11), ('four', '4', 11)]
# fivejtwofive96fiveclc7
#
# []
# [('two', '2', 5), ('two', '2', 5), ('five', '5', 0), ('five', '5', 14), ('five', '5', 0), ('five', '5', 14), ('five', '5', 0), ('five', '5', 14)]
# [('five', '5', 0), ('five', '5', 0), ('five', '5', 0), ('two', '2', 5), ('two', '2', 5), ('five', '5', 14), ('five', '5', 14), ('five', '5', 14)]
# twotwothree22twosevengbqqstsxhqgczp
#
# []
# [('two', '2', 0), ('two', '2', 13), ('two', '2', 0), ('two', '2', 13), ('two', '2', 0), ('two', '2', 13), ('three', '3', 6), ('three', '3', 6), ('seven', '7', 16), ('seven', '7', 16)]
# [('two', '2', 0), ('two', '2', 0), ('two', '2', 0), ('three', '3', 6), ('three', '3', 6), ('two', '2', 13), ('two', '2', 13), ('two', '2', 13), ('seven', '7', 16), ('seven', '7', 16)]
# qgtwonefive3three
#
# []
# [('one', '1', 4), ('one', '1', 4), ('two', '2', 2), ('two', '2', 2), ('three', '3', 12), ('three', '3', 12), ('five', '5', 7), ('five', '5', 7)]
# [('two', '2', 2), ('two', '2', 2), ('one', '1', 4), ('one', '1', 4), ('five', '5', 7), ('five', '5', 7), ('three', '3', 12), ('three', '3', 12)]
# nineeight6nine1three1eight
#
# []
# [('three', '3', 15), ('three', '3', 15), ('eight', '8', 4), ('eight', '8', 21), ('eight', '8', 4), ('eight', '8', 21), ('nine', '9', 0), ('nine', '9', 10), ('nine', '9', 0), ('nine', '9', 10)]
# [('nine', '9', 0), ('nine', '9', 0), ('eight', '8', 4), ('eight', '8', 4), ('nine', '9', 10), ('nine', '9', 10), ('three', '3', 15), ('three', '3', 15), ('eight', '8', 21), ('eight', '8', 21)]
# oneeightndv5
#
# []
# [('one', '1', 0), ('one', '1', 0), ('eight', '8', 3), ('eight', '8', 3)]
# [('one', '1', 0), ('one', '1', 0), ('eight', '8', 3), ('eight', '8', 3)]
# 98eightoneonermnddmgqsseven7
#
# []
# [('one', '1', 7), ('one', '1', 10), ('one', '1', 7), ('one', '1', 10), ('seven', '7', 22), ('seven', '7', 22), ('eight', '8', 2), ('eight', '8', 2)]
# [('eight', '8', 2), ('eight', '8', 2), ('one', '1', 7), ('one', '1', 7), ('one', '1', 10), ('one', '1', 10), ('seven', '7', 22), ('seven', '7', 22)]
# 4l
#
# []
# []
# []
# 6r8xlfznmgffgmrnfsix13rnsv
#
# []
# [('six', '6', 17), ('six', '6', 17)]
# [('six', '6', 17), ('six', '6', 17)]
# 82vvnmv1seven
#
# []
# [('seven', '7', 8), ('seven', '7', 8)]
# [('seven', '7', 8), ('seven', '7', 8)]
# 1nqrqgqjrjqgpxxfrqm
#
# []
# []
# []
# ckdmgxspjfoureightnblkpcfr1
#
# []
# [('four', '4', 9), ('four', '4', 9), ('eight', '8', 13), ('eight', '8', 13)]
# [('four', '4', 9), ('four', '4', 9), ('eight', '8', 13), ('eight', '8', 13)]
# 2threesixqczmrxhdrsevenfour
#
# []
# [('three', '3', 1), ('three', '3', 1), ('four', '4', 23), ('four', '4', 23), ('six', '6', 6), ('six', '6', 6), ('seven', '7', 18), ('seven', '7', 18)]
# [('three', '3', 1), ('three', '3', 1), ('six', '6', 6), ('six', '6', 6), ('seven', '7', 18), ('seven', '7', 18), ('four', '4', 23), ('four', '4', 23)]
# fkpr1seven65nine
#
# []
# [('seven', '7', 5), ('seven', '7', 5), ('nine', '9', 12), ('nine', '9', 12)]
# [('seven', '7', 5), ('seven', '7', 5), ('nine', '9', 12), ('nine', '9', 12)]
# 1ninerr6
#
# []
# [('nine', '9', 1), ('nine', '9', 1)]
# [('nine', '9', 1), ('nine', '9', 1)]
# 5lkr
#
# []
# []
# []
# nft4sevensixslqdfpdlskeight
#
# []
# [('six', '6', 9), ('six', '6', 9), ('seven', '7', 4), ('seven', '7', 4), ('eight', '8', 22), ('eight', '8', 22)]
# [('seven', '7', 4), ('seven', '7', 4), ('six', '6', 9), ('six', '6', 9), ('eight', '8', 22), ('eight', '8', 22)]
# eightfiveone7rdptzjjmmcqone
#
# []
# [('one', '1', 9), ('one', '1', 24), ('one', '1', 9), ('one', '1', 24), ('five', '5', 5), ('five', '5', 5), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('five', '5', 5), ('five', '5', 5), ('one', '1', 9), ('one', '1', 9), ('one', '1', 24), ('one', '1', 24)]
# 6qghmzchmtjktjkbseightczbjmsvmrk88cgctthsbz
#
# []
# [('eight', '8', 17), ('eight', '8', 17)]
# [('eight', '8', 17), ('eight', '8', 17)]
# twozzgrzbgkrkmklkmvfive86five
#
# []
# [('two', '2', 0), ('two', '2', 0), ('five', '5', 19), ('five', '5', 25), ('five', '5', 19), ('five', '5', 25)]
# [('two', '2', 0), ('two', '2', 0), ('five', '5', 19), ('five', '5', 19), ('five', '5', 25), ('five', '5', 25)]
# 4six21xjxqjmqjdlone55three
#
# []
# [('one', '1', 16), ('one', '1', 16), ('three', '3', 21), ('three', '3', 21), ('six', '6', 1), ('six', '6', 1)]
# [('six', '6', 1), ('six', '6', 1), ('one', '1', 16), ('one', '1', 16), ('three', '3', 21), ('three', '3', 21)]
# five42fiveone
#
# []
# [('one', '1', 10), ('one', '1', 10), ('five', '5', 0), ('five', '5', 6), ('five', '5', 0), ('five', '5', 6)]
# [('five', '5', 0), ('five', '5', 0), ('five', '5', 6), ('five', '5', 6), ('one', '1', 10), ('one', '1', 10)]
# eighthc747sevenone
#
# []
# [('one', '1', 15), ('one', '1', 15), ('seven', '7', 10), ('seven', '7', 10), ('eight', '8', 0), ('eight', '8', 0)]
# [('eight', '8', 0), ('eight', '8', 0), ('seven', '7', 10), ('seven', '7', 10), ('one', '1', 15), ('one', '1', 15)]
# four333six6
#
# []
# [('four', '4', 0), ('four', '4', 0), ('six', '6', 7), ('six', '6', 7)]
# [('four', '4', 0), ('four', '4', 0), ('six', '6', 7), ('six', '6', 7)]
# bczkrqdh8one4zqcxrkk
#
# []
# [('one', '1', 9), ('one', '1', 9)]
# [('one', '1', 9), ('one', '1', 9)]
# 3cxhkclpfiveqgsk
#
# []
# [('five', '5', 8), ('five', '5', 8)]
# [('five', '5', 8), ('five', '5', 8)]
# 6eightjnghnlzbhbvnonetwobjfrpnfqsix
#
# []
# [('one', '1', 18), ('one', '1', 18), ('two', '2', 21), ('two', '2', 21), ('six', '6', 32), ('six', '6', 32), ('eight', '8', 1), ('eight', '8', 1)]
# [('eight', '8', 1), ('eight', '8', 1), ('one', '1', 18), ('one', '1', 18), ('two', '2', 21), ('two', '2', 21), ('six', '6', 32), ('six', '6', 32)]
# 4ninecjzlk7nine
#
# []
# [('nine', '9', 1), ('nine', '9', 11), ('nine', '9', 1), ('nine', '9', 11)]
# [('nine', '9', 1), ('nine', '9', 1), ('nine', '9', 11), ('nine', '9', 11)]
# 85four
#
# []
# [('four', '4', 2), ('four', '4', 2)]
# [('four', '4', 2), ('four', '4', 2)]
# mkfcnntfb2ltjnjbslfgvztxgpfcnine6four
#
# []
# [('four', '4', 33), ('four', '4', 33), ('nine', '9', 28), ('nine', '9', 28)]
# [('nine', '9', 28), ('nine', '9', 28), ('four', '4', 33), ('four', '4', 33)]
# zqzllvsdvtwonine4onenineeight
#
# []
# [('one', '1', 17), ('one', '1', 17), ('two', '2', 9), ('two', '2', 9), ('eight', '8', 24), ('eight', '8', 24), ('nine', '9', 12), ('nine', '9', 20), ('nine', '9', 12), ('nine', '9', 20)]
# [('two', '2', 9), ('two', '2', 9), ('nine', '9', 12), ('nine', '9', 12), ('one', '1', 17), ('one', '1', 17), ('nine', '9', 20), ('nine', '9', 20), ('eight', '8', 24), ('eight', '8', 24)]
# 11sixpjjvxbsbjfive
#
# []
# [('five', '5', 14), ('five', '5', 14), ('six', '6', 2), ('six', '6', 2)]
# [('six', '6', 2), ('six', '6', 2), ('five', '5', 14), ('five', '5', 14)]
# 35nhjgtpflthreejqbgvgkdcddpfzfpt
#
# []
# [('three', '3', 10), ('three', '3', 10)]
# [('three', '3', 10), ('three', '3', 10)]
# 9threebcv4sqtrdrgnb
#
# []
# [('three', '3', 1), ('three', '3', 1)]
# [('three', '3', 1), ('three', '3', 1)]
# x4bptzpfgsevenfivenine
#
# []
# [('five', '5', 14), ('five', '5', 14), ('seven', '7', 9), ('seven', '7', 9), ('nine', '9', 18), ('nine', '9', 18)]
# [('seven', '7', 9), ('seven', '7', 9), ('five', '5', 14), ('five', '5', 14), ('nine', '9', 18), ('nine', '9', 18)]
# 1oneqgfpcdntgonectjgnrdxjptfd
#
# []
# [('one', '1', 1), ('one', '1', 13), ('one', '1', 1), ('one', '1', 13)]
# [('one', '1', 1), ('one', '1', 1), ('one', '1', 13), ('one', '1', 13)]
# zrblfddvtgbqtkvddhqzpkk71ldtsixmsjjkr
#
# []
# [('six', '6', 28), ('six', '6', 28)]
# [('six', '6', 28), ('six', '6', 28)]
# three5mjt
#
# []
# [('three', '3', 0), ('three', '3', 0)]
# [('three', '3', 0), ('three', '3', 0)]
# one37ninenineonexjtl2xqhhnmtd
#
# []
# [('one', '1', 0), ('one', '1', 13), ('one', '1', 0), ('one', '1', 13), ('nine', '9', 5), ('nine', '9', 9), ('nine', '9', 5), ('nine', '9', 9)]
# [('one', '1', 0), ('one', '1', 0), ('nine', '9', 5), ('nine', '9', 5), ('nine', '9', 9), ('nine', '9', 9), ('one', '1', 13), ('one', '1', 13)]
# 552oneonehzscghzpqvtndvlpj
#
# []
# [('one', '1', 3), ('one', '1', 6), ('one', '1', 3), ('one', '1', 6)]
# [('one', '1', 3), ('one', '1', 3), ('one', '1', 6), ('one', '1', 6)]
# two8nineeightkfrckndvzhcbdhcdg9
#
# []
# [('two', '2', 0), ('two', '2', 0), ('eight', '8', 8), ('eight', '8', 8), ('nine', '9', 4), ('nine', '9', 4)]
# [('two', '2', 0), ('two', '2', 0), ('nine', '9', 4), ('nine', '9', 4), ('eight', '8', 8), ('eight', '8', 8)]
# hgdjgone22dsdnjjsmjtrxhxssx
#
# []
# [('one', '1', 5), ('one', '1', 5)]
# [('one', '1', 5), ('one', '1', 5)]
# snh6bntph
#
# []
# []
# []
# foureight5nine2
#
# []
# [('four', '4', 0), ('four', '4', 0), ('eight', '8', 4), ('eight', '8', 4), ('nine', '9', 10), ('nine', '9', 10)]
# [('four', '4', 0), ('four', '4', 0), ('eight', '8', 4), ('eight', '8', 4), ('nine', '9', 10), ('nine', '9', 10)]
# 1kjb98
#
# []
# []
# []
# ninetwo2eighttwo
#
# []
# [('two', '2', 4), ('two', '2', 13), ('two', '2', 4), ('two', '2', 13), ('eight', '8', 8), ('eight', '8', 8), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('two', '2', 4), ('two', '2', 4), ('eight', '8', 8), ('eight', '8', 8), ('two', '2', 13), ('two', '2', 13)]
# hpcnone5cjvtpqxhbh596
#
# []
# [('one', '1', 4), ('one', '1', 4)]
# [('one', '1', 4), ('one', '1', 4)]
# 3gbtdlblgp
#
# []
# []
# []
# 4ninemzqkldqrcnmcvjjxtzgbrp
#
# []
# [('nine', '9', 1), ('nine', '9', 1)]
# [('nine', '9', 1), ('nine', '9', 1)]
# fivetwo6
#
# []
# [('two', '2', 4), ('two', '2', 4), ('five', '5', 0), ('five', '5', 0)]
# [('five', '5', 0), ('five', '5', 0), ('two', '2', 4), ('two', '2', 4)]
# 4tlbxgnjgc522zlldmfbmh
#
# []
# []
# []
# fkpsxsmchn3ninesevenseventfxxjdnqxtwo
#
# []
# [('two', '2', 34), ('two', '2', 34), ('seven', '7', 15), ('seven', '7', 20), ('seven', '7', 15), ('seven', '7', 20), ('nine', '9', 11), ('nine', '9', 11)]
# [('nine', '9', 11), ('nine', '9', 11), ('seven', '7', 15), ('seven', '7', 15), ('seven', '7', 20), ('seven', '7', 20), ('two', '2', 34), ('two', '2', 34)]
# sevennine3sixsix
#
# []
# [('six', '6', 10), ('six', '6', 13), ('six', '6', 10), ('six', '6', 13), ('seven', '7', 0), ('seven', '7', 0), ('nine', '9', 5), ('nine', '9', 5)]
# [('seven', '7', 0), ('seven', '7', 0), ('nine', '9', 5), ('nine', '9', 5), ('six', '6', 10), ('six', '6', 10), ('six', '6', 13), ('six', '6', 13)]
# 84s
#
# []
# []
# []
# seven5seven6sixmdfrtwo
#
# []
# [('two', '2', 19), ('two', '2', 19), ('six', '6', 12), ('six', '6', 12), ('seven', '7', 0), ('seven', '7', 6), ('seven', '7', 0), ('seven', '7', 6)]
# [('seven', '7', 0), ('seven', '7', 0), ('seven', '7', 6), ('seven', '7', 6), ('six', '6', 12), ('six', '6', 12), ('two', '2', 19), ('two', '2', 19)]
# one269
#
# []
# [('one', '1', 0), ('one', '1', 0)]
# [('one', '1', 0), ('one', '1', 0)]
# 493nine
#
# []
# [('nine', '9', 3), ('nine', '9', 3)]
# [('nine', '9', 3), ('nine', '9', 3)]
# 29onecklhjcxvpbzfour3
#
# []
# [('one', '1', 2), ('one', '1', 2), ('four', '4', 16), ('four', '4', 16)]
# [('one', '1', 2), ('one', '1', 2), ('four', '4', 16), ('four', '4', 16)]
# 35vksqxhbnxk
#
# []
# []
# []
# sixfdqttpskdnbksqxg9three6bqqpngfhz
#
# []
# [('three', '3', 20), ('three', '3', 20), ('six', '6', 0), ('six', '6', 0)]
# [('six', '6', 0), ('six', '6', 0), ('three', '3', 20), ('three', '3', 20)]
# 55260

# %%
parse_numbers('ninetwo2eighttwo')
# Out:
# ninetwo2eighttwo
# []
# [('two', '2', 4), ('two', '2', 13), ('two', '2', 4), ('two', '2', 13), ('eight', '8', 8), ('eight', '8', 8), ('nine', '9', 0), ('nine', '9', 0)]
# [('nine', '9', 0), ('nine', '9', 0), ('two', '2', 4), ('two', '2', 4), ('eight', '8', 8), ('eight', '8', 8), ('two', '2', 13), ('two', '2', 13)]
# '922eight2'

# %%
'9two28two'.findall('two')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 '9two28two'.findall('two')
#
# AttributeError: 'str' object has no attribute 'findall'

# %%
re.findall('two','9two28two')
# Out:
# ['two', 'two']

# %%
'9two28two'.rfind('two')
# Out:
# 6

# %%
'9two28two'.find('two')
# Out:
# 1
